// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
float S = 200;   //valor da primeira parcela
int N = 5;       //número de parcelas
float J = 1;     //percentual de juros mensal
float P = S;     //valor da parcela corrente

System.out.print("Parcelas do financiamento: ");
for (int i = 1; i <= N; i++) {
    System.out.print(P + "; ");
    P = P*(1 + J/100);
}
// Out:
// Parcelas do financiamento: 200.0; 202.0; 204.02; 206.0602; 208.12079;
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Emprestimo {
    
    static float calcularParcela(float S, int N, float J, float P, int atual) {
        if (atual == 1) {
            return S;
        }
        
        else if (atual <= N)
            return P*(1 + J/100);
    
        else
            return 0;
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkrdaf85bc2.Emprestimo

// %%
float S = 200;   //valor da primeira parcela
int N = 5;       //número de parcelas
float J = 1;     //percentual de juros mensal
float P = S;     //valor da parcela corrente

for (int i = 1; i <= N; i++) {
    P = Emprestimo.calcularParcela(S, N, J, P, i);
    System.out.println("O valor da parcela " + i + " eh " + P);
}
// Out:
// O valor da parcela 1 eh 200.0
// O valor da parcela 2 eh 202.0
// O valor da parcela 3 eh 204.02
// O valor da parcela 4 eh 206.0602
// O valor da parcela 5 eh 208.12079
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
public class conversor {
    
    static String decimalToBinary(int n) {
        String binary = "";
        int dividendo = n, resto, quociente;
        
        do {
            quociente = dividendo/2;
            resto = dividendo % 2;
            binary = resto + binary;
            dividendo = quociente;
        } while(dividendo >= 1);
        
        return binary;
    }
    
}

// %%
import java.util.Random;

Random rand = new Random();
int n = rand.nextInt(10000);

System.out.println("O número sorteado é: " + n);
System.out.println("Sua versão binária é: " + conversor.decimalToBinary(n));
// Out:
// O número sorteado é: 296
// Sua versão binária é: 100101000
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class Transcricao {
    
    static String codificaCadeia(String sequencia) {
        int n = sequencia.length();
        String RNA = "";
        for (int i = 0; i < n; i++) {
            char c = sequencia.charAt(i);
            switch (c) {
                case 'A':
                    RNA += 'U';
                    break;
                
                case 'G':
                    RNA += 'C';
                    break;
                    
                case 'C':
                    RNA += 'G';
                    break;
                    
                case 'T':
                    RNA += 'A';
                    break;
            }
        }
        return RNA;
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkr9b684947.Transcricao

// %%
String DNA = "ATTACGCGCAAAC";
System.out.println(Transcricao.codificaCadeia(DNA));
// Out:
// UAAUGCGCGUUUG
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
public class Empresa {
    
    static float salarioMedio(int salarios[]) {
        int total = 0;
        for (int i = 0; i < salarios.length; i++) {
            total += salarios[i];
        }
        float media = total/salarios.length;
        return media;
    }
    
    static int qtdAcimaMedia(int salarios[], float media) {
        int qtd = 0;
        for (int i = 0; i < salarios.length; i++) {
            qtd += (salarios[i] > media ? 1 : 0);
        }
        return qtd;
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkrdaf85bc2.Empresa

// %%
/*
Para gerar valores entre um intervalo [min, max] podemos usar a seguinte
fórmula: rand.nextInt((max - min) + 1) + min;
No nosso caso, temos que min = 2500 e max = 15000
*/

import java.util.Random;

Random rand = new Random();
int n = 50;  //numero de funcionarios da empresa
int salarios[] = new int[n];

for (int i = 0; i < n; i++) {
    salarios[i] = rand.nextInt(12501) + 2500;
    System.out.println("O funcionário " + (i+1) + " recebe R$ "  + salarios[i]);
}

float mediaSalarios = Empresa.salarioMedio(salarios);
System.out.println("Portanto, o salário médio é: R$ " + mediaSalarios);

System.out.println("De " + n + " funcionarios, " + Empresa.qtdAcimaMedia(salarios, mediaSalarios) + " ganham acima da média.");
// Out:
// O funcionário 1 recebe R$ 7127
// O funcionário 2 recebe R$ 13761
// O funcionário 3 recebe R$ 9489
// O funcionário 4 recebe R$ 13683
// O funcionário 5 recebe R$ 13493
// O funcionário 6 recebe R$ 7360
// O funcionário 7 recebe R$ 6949
// O funcionário 8 recebe R$ 7245
// O funcionário 9 recebe R$ 8175
// O funcionário 10 recebe R$ 4218
// O funcionário 11 recebe R$ 8004
// O funcionário 12 recebe R$ 11951
// O funcionário 13 recebe R$ 4229
// O funcionário 14 recebe R$ 2884
// O funcionário 15 recebe R$ 4045
// O funcionário 16 recebe R$ 7198
// O funcionário 17 recebe R$ 4821
// O funcionário 18 recebe R$ 11203
// O funcionário 19 recebe R$ 13923
// O funcionário 20 recebe R$ 12751
// O funcionário 21 recebe R$ 13433
// O funcionário 22 recebe R$ 3791
// O funcionário 23 recebe R$ 7405
// O funcionário 24 recebe R$ 5058
// O funcionário 25 recebe R$ 6513
// O funcionário 26 recebe R$ 9853
// O funcionário 27 recebe R$ 8120
// O funcionário 28 recebe R$ 5409
// O funcionário 29 recebe R$ 5163
// O funcionário 30 recebe R$ 12383
// O funcionário 31 recebe R$ 9244
// O funcionário 32 recebe R$ 8936
// O funcionário 33 recebe R$ 9905
// O funcionário 34 recebe R$ 5163
// O funcionário 35 recebe R$ 6711
// O funcionário 36 recebe R$ 7408
// O funcionário 37 recebe R$ 7525
// O funcionário 38 recebe R$ 6651
// O funcionário 39 recebe R$ 2614
// O funcionário 40 recebe R$ 7908
// O funcionário 41 recebe R$ 3838
// O funcionário 42 recebe R$ 13912
// O funcionário 43 recebe R$ 7078
// O funcionário 44 recebe R$ 3239
// O funcionário 45 recebe R$ 7755
// O funcionário 46 recebe R$ 10584
// O funcionário 47 recebe R$ 13180
// O funcionário 48 recebe R$ 6010
// O funcionário 49 recebe R$ 6851
// O funcionário 50 recebe R$ 11216
// Portanto, o salário médio é: R$ 8107.0
// De 50 funcionarios, 20 ganham acima da média.
// null
